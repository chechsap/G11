# %%
import pandas as pd
import numpy as np

# %%
#FIES Microdata  (DF_FIES2018_MICRO)

url_2018_fies_micro = 'https://raw.githubusercontent.com/chechsap/G11/master/2018%20PSA%20FIES%20Microdata.csv'

df_fies2018_micro = pd.read_csv(url_2018_fies_micro, encoding='latin1')
df_fies2018_micro.head()
# Out:
#    Region  Province  Sequence no.  Family SIze  \
# 0       1        28             1          1.0
# 1       1        28             2          6.0
# 2       1        28             3          3.0
# 3       1        28             4          4.0
# 4       1        28             5          3.0
#
#    Salaries/Wages from Regular Employment  \
# 0                                       0
# 1                                       0
# 2                                   86840
# 3                                       0
# 4                                  101896
#
#    Salaries/Wages from Seasonal Employment  \
# 0                                        0
# 1                                    79800
# 2                                    32710
# 3                                        0
# 4                                    34000
#
#    Salaries/Wages from both Agri and Non-Agri Activities  \
# 0                                                  0
# ...

# %%
#Unemployment   (DF_UNEMP)
# url_unemployment = 'https://raw.githubusercontent.com/chechsap/G11/master/Unemployment%20Data.xlsx'

# df_unemp = pd.read_excel(url_unemployment)

# df_unemp.head()
# display(df_unemp.dtypes)

# %%
#2018 FIES Table1  (DF_FIES2018)

url_2018_table1 = 'https://raw.githubusercontent.com/chechsap/G11/master/2018%20Table%201.csv'

df_fies2018 = pd.read_csv(url_2018_table1)
df_fies2018.head()
# display(df_fies2018.dtypes)
# Out:
#                                    Region  Number of Families (In thousands)  \
# 0           National Capital Region (NCR)                               3318
# 1  Cordillera Administrative Region (CAR)                                422
# 2                Region I (Ilocos Region)                               1213
# 3              Region II (Cagayan Valley)                                853
# 4              Region III (Central Luzon)                               2783
#
#    Total Income (In millions)  Average Income (In thousands)  \
# 0                     1527770                            460
# 1                      149519                            354
# 2                      348097                            287
# 3                      225945                            265
# 4                      929598                            334
#
#    Expenditure Total (In millions)  Expenditure Average (In thousands)
# ...

# %%
#2015 FIES Table1  (DF_FIES2015)

url_2015_table1 = 'https://raw.githubusercontent.com/chechsap/G11/master/2015%20Table%201.csv'

df_fies2015 = pd.read_csv(url_2015_table1)
df_fies2015.head()
# display(df_fies2015.dtypes)
# Out:
#                                    Region  Number of Families (In thousands)  \
# 0           National Capital Region (NCR)                               3019
# 1  Cordillera Administrative Region (CAR)                                402
# 2                Region I (Ilocos Region)                               1170
# 3              Region II (Cagayan Valley)                                816
# 4              Region III (Central Luzon)                               2507
#
#    Total Income (In millions)  Average Income (In thousands)  \
# 0                     1282823                            425
# 1                      113531                            282
# 2                      278515                            238
# 3                      193589                            237
# 4                      750054                            299
#
#    Expenditure Total (In millions)  Expenditure Average (In thousands)
# ...

# %%
#2012 FIES Table1  (DF_FIES2012)

url_2012_table1 = 'https://raw.githubusercontent.com/chechsap/G11/master/2012%20Table%201.csv'

df_fies2012 = pd.read_csv(url_2012_table1)
df_fies2012.head()
# display(df_fies2012.dtypes)
# Out:
#                                    Region  Number of Families (In thousands)  \
# 0           National Capital Region (NCR)                               2917
# 1  Cordillera Administrative Region (CAR)                                375
# 2                Region I (Ilocos Region)                               1105
# 3              Region II (Cagayan Valley)                                771
# 4              Region III (Central Luzon)                               2386
#
#    Total Income (In millions)  Average Income (In thousands)  \
# 0                     1106169                            379
# 1                       96351                            257
# 2                      225050                            204
# 3                      150089                            195
# 4                      618893                            259
#
#    Expenditure Total (In millions)  Expenditure Average (In thousands)
# ...

# %%
mic18 = df_fies2018_micro.copy()
mic18.shape

mic18['FreeCashFlow'] = mic18['Total Disbursemets']
# Out:
# (147717, 85)
